# %%
from metrics import Metrics
import matplotlib.pyplot as plt

# %%
metrics = Metrics(load=True)
metrics.list_metrics()
# Out:
# {'DIAYN': {'x_y_location_metrics': ['Ant-v5', 'Quadruped', 'Humanoid'],
#   'x_location_metrics': ['Cheetah']},
#  'DADS': {'x_y_location_metrics': ['Ant-v5', 'Quadruped', 'Humanoid'],
#   'x_location_metrics': ['Cheetah']},
#  'TIME_16': {'x_y_location_metrics': ['Quadruped', 'Ant-v5', 'Humanoid'],
#   'x_location_metrics': ['Cheetah'],
#   'trajectory_embeddings': ['Ant-v5']},
#  'TIME_32': {'x_y_location_metrics': ['Quadruped', 'Ant-v5', 'Humanoid'],
#   'x_location_metrics': ['Cheetah'],
#   'trajectory_embeddings': ['Ant-v5']},
#  'TIME_64': {'x_y_location_metrics': ['Quadruped', 'Ant-v5', 'Humanoid'],
#   'x_location_metrics': ['Cheetah'],
#   'returns': ['HumanoidGoal', 'QuadrupedGoal', 'AntMazeMultiGoal'],
#   'trajectory_embeddings': ['Ant-v5']},
#  'METRA': {'x_y_location_metrics': ['Quadruped', 'Humanoid', 'Ant-v5'],
#   'x_location_metrics': ['Cheetah'],
#   'returns': ['HumanoidGoal', 'QuadrupedGoal', 'AntMazeMultiGoal']},
# ...

# %%
row = 4
col = 6
fig, axes = plt.subplots(row, col, figsize=(8 * col, 8 * row))

# Ant
# metrics.plot_x_y_explore_metrics("TIME_16", "Ant-v5", x_lim=(-50, 50), y_lim=(-50, 50), ax=axes[0][0], custom_title=" ")
# metrics.plot_x_y_explore_metrics("TIME_32", "Ant-v5", x_lim=(-50, 50), y_lim=(-50, 50), ax=axes[0][1], custom_title=" ")
metrics.plot_x_y_explore_metrics("TIME", "Ant-v5", x_lim=(-50, 50), y_lim=(-50, 50), ax=axes[0][0], custom_title=" ")
metrics.plot_x_y_explore_metrics("RSD", "Ant-v5", x_lim=(-50, 50), y_lim=(-50, 50), ax=axes[0][1], custom_title=" ")
metrics.plot_x_y_explore_metrics("METRA", "Ant-v5", x_lim=(-50, 50), y_lim=(-50, 50), ax=axes[0][2], custom_title=" ")
metrics.plot_x_y_explore_metrics("DUSDi", "Ant-v5", x_lim=(-50, 50), y_lim=(-50, 50), ax=axes[0][3], custom_title=" ")
metrics.plot_x_y_explore_metrics("DADS", "Ant-v5", x_lim=(-50, 50), y_lim=(-50, 50), ax=axes[0][4], custom_title=" ")
metrics.plot_x_y_explore_metrics("DIAYN", "Ant-v5", x_lim=(-50, 50), y_lim=(-50, 50), ax=axes[0][5], custom_title=" ")

# Cheetah
# metrics.plot_x_location_metrics("TIME_16", "Cheetah", x_lim=(-100, 100), ax=axes[1][0], custom_title=" ")
# metrics.plot_x_location_metrics("TIME_32", "Cheetah", x_lim=(-100, 100), ax=axes[1][1], custom_title=" ")
metrics.plot_x_location_metrics("TIME", "Cheetah", x_lim=(-100, 100), ax=axes[1][0], custom_title=" ")
metrics.plot_x_location_metrics("RSD", "Cheetah", x_lim=(-100, 100), ax=axes[1][1], custom_title=" ")
metrics.plot_x_location_metrics("METRA", "Cheetah", x_lim=(-100, 100), ax=axes[1][2], custom_title=" ")
metrics.plot_x_location_metrics("DUSDi", "Cheetah", x_lim=(-100, 100), ax=axes[1][3], custom_title=" ")
metrics.plot_x_location_metrics("DADS", "Cheetah", x_lim=(-100, 100), ax=axes[1][4], custom_title=" ")
metrics.plot_x_location_metrics("DIAYN", "Cheetah", x_lim=(-100, 100), ax=axes[1][5], custom_title=" ")

# Quadruped
# metrics.plot_x_y_explore_metrics("TIME_16", "Quadruped", x_lim=(-15, 15), y_lim=(-15, 15), ax=axes[2][0], custom_title=" ")
# metrics.plot_x_y_explore_metrics("TIME_32", "Quadruped", x_lim=(-15, 15), y_lim=(-15, 15), ax=axes[2][1], custom_title=" ")
metrics.plot_x_y_explore_metrics("TIME", "Quadruped", x_lim=(-15, 15), y_lim=(-15, 15), ax=axes[2][0], custom_title=" ")
metrics.plot_x_y_explore_metrics("RSD", "Quadruped", x_lim=(-15, 15), y_lim=(-15, 15), ax=axes[2][1], custom_title=" ")
metrics.plot_x_y_explore_metrics("METRA", "Quadruped", x_lim=(-15, 15), y_lim=(-15, 15), ax=axes[2][2], custom_title=" ")
metrics.plot_x_y_explore_metrics("DUSDi", "Quadruped", x_lim=(-15, 15), y_lim=(-15, 15), ax=axes[2][3], custom_title=" ")
metrics.plot_x_y_explore_metrics("DADS", "Quadruped", x_lim=(-15, 15), y_lim=(-15, 15), ax=axes[2][4], custom_title=" ")
metrics.plot_x_y_explore_metrics("DIAYN", "Quadruped", x_lim=(-15, 15), y_lim=(-15, 15), ax=axes[2][5], custom_title=" ")

# # Humanoid
# metrics.plot_x_y_explore_metrics("TIME_16", "Humanoid", x_lim=(-10, 10), y_lim=(-10, 10), ax=axes[3][0], custom_title=" ")
# metrics.plot_x_y_explore_metrics("TIME_32", "Humanoid", x_lim=(-10, 10), y_lim=(-10, 10), ax=axes[3][1], custom_title=" ")
metrics.plot_x_y_explore_metrics("TIME", "Humanoid", x_lim=(-10, 10), y_lim=(-10, 10), ax=axes[3][0], custom_title=" ")
metrics.plot_x_y_explore_metrics("RSD", "Humanoid", x_lim=(-10, 10), y_lim=(-10, 10), ax=axes[3][1], custom_title=" ")
metrics.plot_x_y_explore_metrics("METRA", "Humanoid", x_lim=(-10, 10), y_lim=(-10, 10), ax=axes[3][2], custom_title=" ")
metrics.plot_x_y_explore_metrics("DUSDi", "Humanoid", x_lim=(-10, 10), y_lim=(-10, 10), ax=axes[3][3], custom_title=" ")
metrics.plot_x_y_explore_metrics("DADS", "Humanoid", x_lim=(-10, 10), y_lim=(-10, 10), ax=axes[3][4], custom_title=" ")
metrics.plot_x_y_explore_metrics("DIAYN", "Humanoid", x_lim=(-10, 10), y_lim=(-10, 10), ax=axes[3][5], custom_title=" ")

# %%
metrics.plot_state_coverage_from_env('Cheetah', window_size=1)

# %%
ret = metrics.plot_percentage_state_coverage(['METRA', 'DUSDi', "RSD", "TIME"], 'Ant-v5', window_size=1.8, lower_bound=2, upper_bound=10)

# %%
ret = metrics.plot_percentage_state_coverage(['METRA', 'DUSDi', "RSD", "TIME"], 'Quadruped', window_size=0.5, lower_bound=2, upper_bound=10)

# %%
ret = metrics.plot_percentage_state_coverage(['METRA', 'DUSDi', "RSD", "TIME"], 'Humanoid', window_size=0.5, lower_bound=2, upper_bound=10)

# %%
ret['METRA'][-1]
# Out:
# 0.23163841807909605

# %%
len(metrics.metrics['METRA']['x_y_location_metrics']['Ant-v5'])
# Out:
# 48

# %%
row = 1
col = 3
fig, axes = plt.subplots(row, col, figsize=(8 * col, 8 * row))

metrics.plot_running_returns(["METRA", "RSD", "DUSDi", "TIME"], "AntMazeMultiGoal", custom_title="AntMazeMultiGoal", window=10000, y_lim=(0, 1), legend=False, ax=axes[0])
metrics.plot_running_returns(["METRA", "RSD", "DUSDi", "TIME"], "QuadrupedGoal", custom_title="QuadrupedGoal", window=10000, y_lim=(1, 7), legend=False, ax=axes[1])
metrics.plot_running_returns(["METRA", "RSD", "DUSDi", "TIME"], "HumanoidGoal", custom_title="HumanoidGoal", window=10000, y_lim=(0, 6), legend=False, ax=axes[2])
plt.legend()

# %%
import numpy as np

# %%
algonames = ["METRA", "RSD", "DUSDi", "TIME_64"]
envs = ["AntMazeMultiGoal", "QuadrupedGoal", "HumanoidGoal"]

for algoname in algonames:
    for env in envs:
        temp = np.array(metrics.metrics[algoname]["returns"][env])
        sample = temp.reshape(10000, 10).mean(axis=1)

        metrics.metrics[algoname]["returns"][env] = sample.tolist()
